# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:DSEfe0507727182@127.0.0.1:3306/clevelanddata

# %%
# %%sql
#
# SELECT *
# FROM cleveland1
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(40, 1, 2, 140, 289, 0, 0, 172, 0, 0.0, 1, 0),
#  (49, 0, 3, 160, 180, 0, 0, 156, 0, 1.0, 2, 1),
#  (37, 1, 2, 130, 283, 0, 1, 98, 0, 0.0, 1, 0),
#  (48, 0, 4, 138, 214, 0, 0, 108, 1, 1.5, 2, 1),
#  (54, 1, 3, 150, 195, 0, 0, 122, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# ALTER TABLE cleveland1
# RENAME COLUMN `resting bp s`
# TO restbps;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nALTER TABLE cleveland1 \nRENAME COLUMN `resting bp s`\nTO restbps;\n')
#
# File ~\anaconda3\envs\sql_new\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
#
# SELECT COUNT(*) as Total_No_of_Rows
# FROM cleveland1
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 1 rows affected.
# [(1190,)]

# %%
# %%sql
#
# SHOW COLUMNS
# FROM cleveland1
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 12 rows affected.
# [('age', 'int', 'YES', '', None, ''),
#  ('sex', 'int', 'YES', '', None, ''),
#  ('chest pain type', 'int', 'YES', '', None, ''),
#  ('resting bp s', 'int', 'YES', '', None, ''),
#  ('cholesterol', 'int', 'YES', '', None, ''),
#  ('fasting blood sugar', 'int', 'YES', '', None, ''),
#  ('resting ecg', 'int', 'YES', '', None, ''),
#  ('max heart rate', 'int', 'YES', '', None, ''),
#  ('exercise angina', 'int', 'YES', '', None, ''),
#  ('oldpeak', 'double', 'YES', '', None, ''),
#  ('ST slope', 'int', 'YES', '', None, ''),
#  ('target', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT *
# FROM cleveland2
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 52, 1, 0, 125, 212, 0, 1, 168, 0, 1.0, 2, 2, 3, 0),
#  (1, 53, 1, 0, 140, 203, 1, 0, 155, 1, 3.1, 0, 0, 3, 0),
#  (2, 70, 1, 0, 145, 174, 0, 1, 125, 1, 2.6, 0, 0, 3, 0),
#  (3, 61, 1, 0, 148, 203, 0, 1, 161, 0, 0.0, 2, 1, 3, 0),
#  (4, 62, 0, 0, 138, 294, 1, 1, 106, 0, 1.9, 1, 3, 2, 0)]

# %%
# %%sql
#
# ALTER TABLE cleveland2
# RENAME COLUMN trestbps
# TO restbps
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nALTER TABLE cleveland2 \nRENAME COLUMN trestbps\nTO restbps\n')
#
# File ~\anaconda3\envs\sql_new\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
#
# ALTER MyUnknownColumn RENAME AS S_N
# FROM cleveland2
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'MyUnknownColumn RENAME AS S_N\nFROM cleveland2' at line 1")
# [SQL: ALTER MyUnknownColumn RENAME AS S_N
# FROM cleveland2]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# ALTER TABLE cleveland2
# RENAME COLUMN MyUnknownColumn
# TO s_n;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nALTER TABLE cleveland2 \nRENAME COLUMN MyUnknownColumn\nTO s_n;\n')
#
# File ~\anaconda3\envs\sql_new\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
#
# SELECT *
# FROM cleveland2
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 52, 1, 0, 125, 212, 0, 1, 168, 0, 1.0, 2, 2, 3, 0),
#  (1, 53, 1, 0, 140, 203, 1, 0, 155, 1, 3.1, 0, 0, 3, 0),
#  (2, 70, 1, 0, 145, 174, 0, 1, 125, 1, 2.6, 0, 0, 3, 0),
#  (3, 61, 1, 0, 148, 203, 0, 1, 161, 0, 0.0, 2, 1, 3, 0),
#  (4, 62, 0, 0, 138, 294, 1, 1, 106, 0, 1.9, 1, 3, 2, 0)]

# %%
# %%sql
#
# SELECT COUNT(*) as Total_No_of_Rows
# FROM cleveland2
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 1 rows affected.
# [(302,)]

# %%
# %%sql
#
# SHOW COLUMNS
# FROM cleveland2
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 15 rows affected.
# [('MyUnknownColumn', 'int', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('sex', 'int', 'YES', '', None, ''),
#  ('cp', 'int', 'YES', '', None, ''),
#  ('trestbps', 'int', 'YES', '', None, ''),
#  ('chol', 'int', 'YES', '', None, ''),
#  ('fbs', 'int', 'YES', '', None, ''),
#  ('restecg', 'int', 'YES', '', None, ''),
#  ('thalach', 'int', 'YES', '', None, ''),
#  ('exang', 'int', 'YES', '', None, ''),
#  ('oldpeak', 'double', 'YES', '', None, ''),
#  ('slope', 'int', 'YES', '', None, ''),
#  ('ca', 'int', 'YES', '', None, ''),
#  ('thal', 'int', 'YES', '', None, ''),
#  ('target', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT COUNT(*) as Total_No_of_Rows
# FROM cleveland_dataset_heart_dx
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 1 rows affected.
# [(1048,)]

# %%
# %%sql
#
# SELECT *
# FROM cleveland_dataset_heart_dx
#
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 40, 1, 2, 140, 289.0, 0, 0, 172, 0, 0.0, 1, 0),
#  (1, 49, 0, 3, 160, 180.0, 0, 0, 156, 0, 1.0, 2, 1),
#  (2, 37, 1, 2, 130, 283.0, 0, 1, 98, 0, 0.0, 1, 0),
#  (3, 48, 0, 4, 138, 214.0, 0, 0, 108, 1, 1.5, 2, 1),
#  (4, 54, 1, 3, 150, 195.0, 0, 0, 122, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# SHOW COLUMNS
# FROM cleveland_dataset_heart_dx
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 13 rows affected.
# [('MyUnknownColumn', 'int', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('sex', 'int', 'YES', '', None, ''),
#  ('chest pain type', 'int', 'YES', '', None, ''),
#  ('resting bps', 'int', 'YES', '', None, ''),
#  ('cholesterol', 'double', 'YES', '', None, ''),
#  ('fasting blood sugar', 'int', 'YES', '', None, ''),
#  ('resting ecg', 'int', 'YES', '', None, ''),
#  ('max heart rate', 'int', 'YES', '', None, ''),
#  ('exercise angina', 'int', 'YES', '', None, ''),
#  ('oldpeak', 'double', 'YES', '', None, ''),
#  ('ST slope', 'int', 'YES', '', None, ''),
#  ('target', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# ALTER TABLE cleveland_dataset_heart_dx
# RENAME COLUMN MyUnknownColumn
# TO s_n;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nALTER TABLE cleveland_dataset_heart_dx \nRENAME COLUMN MyUnknownColumn\nTO s_n;\n')
#
# File ~\anaconda3\envs\sql_new\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
#
# SELECT *
# FROM cleveland_dataset_heart_dx
#
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 40, 1, 2, 140, 289.0, 0, 0, 172, 0, 0.0, 1, 0),
#  (1, 49, 0, 3, 160, 180.0, 0, 0, 156, 0, 1.0, 2, 1),
#  (2, 37, 1, 2, 130, 283.0, 0, 1, 98, 0, 0.0, 1, 0),
#  (3, 48, 0, 4, 138, 214.0, 0, 0, 108, 1, 1.5, 2, 1),
#  (4, 54, 1, 3, 150, 195.0, 0, 0, 122, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# SELECT
#     cholesterol,
#     COUNT(cholesterol) as freq_of_sex
# FROM cleveland_dataset_heart_dx
# GROUP BY sex
# ORDER BY freq_of_sex DESC
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(1, 770), (0, 278)]

# %%
# %%sql
#
# SELECT
#     sex,
#     COUNT(sex) as freq_of_sex
# FROM cleveland2
# GROUP BY sex
# ORDER BY freq_of_sex DESC
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(1, 206), (0, 96)]

# %%
# %%sql
#
# SELECT
#     `chest pain type`,
#     COUNT(`chest pain type`) as freq_of_cpt
# FROM cleveland_dataset_heart_dx
# GROUP BY `chest pain type`
# ORDER BY freq_of_cpt DESC
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 4 rows affected.
# [(4, 393), (3, 255), (2, 216), (1, 184)]

# %%
# %%sql
#
# SELECT
#     `chest pain type`,
#     COUNT(`chest pain type`) as freq_of_cpt
# FROM cleveland_dataset_heart_dx
# GROUP BY `chest pain type`
# ORDER BY freq_of_cpt DESC

# %%
# %%sql
#
# SELECT
#     sex,
#     COUNT(sex) as freq_of_sex
# FROM cleveland1
# GROUP BY sex
# ORDER BY freq_of_sex DESC
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(1, 909), (0, 281)]

# %%
# %%sql
#
# SELECT
#     `chest pain type`,
#     COUNT(`chest pain type`) as freq_of_cpt
# FROM cleveland1
# GROUP BY `chest pain type`
# ORDER BY freq_of_cpt DESC
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 4 rows affected.
# [(4, 625), (3, 283), (2, 216), (1, 66)]

# %%
# %%sql
#
#
# SELECT
#     cholesterol,
# FLOOR(cholesterol / 10) * 10 AS cholesterol,
# AVG(cholesterol) as freq_of_avgcholesterol
# FROM cleveland_dataset_heart_dx
# GROUP BY cholesterol;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 221 rows affected.
# [(289.0, 280.0, 289.0),
#  (180.0, 180.0, 180.0),
#  (283.0, 280.0, 283.0),
#  (214.0, 210.0, 214.0),
#  (195.0, 190.0, 195.0),
#  (339.0, 330.0, 339.0),
#  (237.0, 230.0, 237.0),
#  (208.0, 200.0, 208.0),
#  (207.0, 200.0, 207.0),
#  (284.0, 280.0, 284.0),
#  (211.0, 210.0, 211.0),
#  (164.0, 160.0, 164.0),
#  (204.0, 200.0, 204.0),
#  (234.0, 230.0, 234.0),
#  (273.0, 270.0, 273.0),
#  (196.0, 190.0, 196.0),
#  (201.0, 200.0, 201.0),
#  (248.0, 240.0, 248.0),
#  (267.0, 260.0, 267.0),
#  (223.0, 220.0, 223.0),
#  (184.0, 180.0, 184.0),
#  (288.0, 280.0, 288.0),
#  (215.0, 210.0, 215.0),
#  (209.0, 200.0, 209.0),
#  (260.0, 260.0, 260.0),
#  (468.0, 460.0, 468.0),
#  (188.0, 180.0, 188.0),
#  (518.0, 510.0, 518.0),
#  (167.0, 160.0, 167.0),
#  (224.0, 220.0, 224.0),
#  (172.0, 170.0, 172.0),
#  (186.0, 180.0, 186.0),
#  (254.0, 250.0, 254.0),
#  (306.0, 300.0, 306.0),
#  (250.0, 250.0, 250.0),
# ...

# %%
# %%sql
#
#
# SELECT
# FLOOR(age / 10) * 10 AS age_group,
# AVG(cholesterol) as freq_of_avgcholesterol
# FROM cleveland_dataset_heart_dx
# GROUP BY age_group
# ORDER BY freq_of_avgcholesterol;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 6 rows affected.
# [(20, 209.2),
#  (30, 231.4125),
#  (70, 234.77142857142857),
#  (40, 240.1102661596958),
#  (50, 246.8271028037383),
#  (60, 254.74261603375527)]

# %%
# %%sql
#
# SELECT *
# FROM cleveland_dataset_heart_dx
#
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 40, 1, 2, 140, 289.0, 0, 0, 172, 0, 0.0, 1, 0),
#  (1, 49, 0, 3, 160, 180.0, 0, 0, 156, 0, 1.0, 2, 1),
#  (2, 37, 1, 2, 130, 283.0, 0, 1, 98, 0, 0.0, 1, 0),
#  (3, 48, 0, 4, 138, 214.0, 0, 0, 108, 1, 1.5, 2, 1),
#  (4, 54, 1, 3, 150, 195.0, 0, 0, 122, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# ALTER TABLE cleveland_dataset_heart_dx
# RENAME COLUMN `resting bps`
# TO restbps
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nALTER TABLE cleveland_dataset_heart_dx \nRENAME COLUMN `resting bps`\nTO restbps\n')
#
# File ~\anaconda3\envs\sql_new\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
#
# SELECT *
# FROM cleveland_dataset_heart_dx
#
# LIMIT 2
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(0, 40, 1, 2, 140, 289.0, 0, 0, 172, 0, 0.0, 1, 0),
#  (1, 49, 0, 3, 160, 180.0, 0, 0, 156, 0, 1.0, 2, 1)]

# %%
# %%sql
#
# SELECT *
# FROM cleveland1
# ORDER BY age
#
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(28, 1, 2, 130, 132, 0, 2, 185, 0, 0.0, 1, 0),
#  (29, 1, 2, 130, 204, 0, 2, 202, 0, 0.0, 1, 0),
#  (29, 1, 2, 130, 204, 0, 2, 202, 0, 0.0, 1, 0),
#  (29, 1, 2, 120, 243, 0, 0, 160, 0, 0.0, 1, 0),
#  (29, 1, 2, 140, 263, 0, 0, 170, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# SELECT *
# FROM cleveland2
# ORDER BY age
# LIMIT 25
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 25 rows affected.
# [(60, 29, 1, 1, 130, 204, 0, 0, 202, 0, 0.0, 2, 0, 2, 1),
#  (143, 34, 1, 3, 118, 182, 0, 0, 174, 0, 0.0, 2, 0, 2, 1),
#  (12, 34, 0, 1, 118, 210, 0, 1, 192, 0, 0.7, 2, 0, 2, 1),
#  (256, 35, 0, 0, 138, 183, 0, 1, 182, 0, 1.4, 2, 0, 2, 1),
#  (281, 35, 1, 1, 122, 192, 0, 1, 174, 0, 0.0, 2, 0, 2, 1),
#  (384, 35, 1, 0, 126, 282, 0, 0, 156, 1, 0.0, 2, 0, 3, 0),
#  (254, 35, 1, 0, 120, 198, 0, 1, 130, 1, 1.6, 1, 0, 3, 0),
#  (68, 37, 0, 2, 120, 215, 0, 1, 170, 0, 0.0, 2, 0, 2, 1),
#  (332, 37, 1, 2, 130, 250, 0, 1, 187, 0, 3.5, 0, 0, 2, 1),
#  (52, 38, 1, 2, 138, 175, 0, 1, 173, 0, 0.0, 2, 4, 2, 1),
#  (258, 38, 1, 3, 120, 231, 0, 1, 182, 1, 3.8, 1, 0, 3, 0),
#  (149, 39, 1, 2, 140, 321, 0, 0, 182, 0, 0.0, 2, 0, 2, 1),
#  (173, 39, 0, 2, 94, 199, 0, 1, 179, 0, 0.0, 2, 0, 2, 1),
#  (248, 39, 0, 2, 138, 220, 0, 1, 152, 0, 0.0, 1, 0, 2, 1),
#  (694, 39, 1, 0, 118, 219, 0, 1, 140, 0, 1.2, 1, 0, 3, 0),
# ...

# %%
# %%sql
#
# SELECT *
# FROM cleveland_dataset_heart_dx
#
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(0, 40, 1, 2, 140, 289.0, 0, 0, 172, 0, 0.0, 1, 0),
#  (1, 49, 0, 3, 160, 180.0, 0, 0, 156, 0, 1.0, 2, 1),
#  (2, 37, 1, 2, 130, 283.0, 0, 1, 98, 0, 0.0, 1, 0),
#  (3, 48, 0, 4, 138, 214.0, 0, 0, 108, 1, 1.5, 2, 1),
#  (4, 54, 1, 3, 150, 195.0, 0, 0, 122, 0, 0.0, 1, 0)]

# %%
# %%sql
#
# SELECT restbps, `exercise angina`
# FROM cleveland_dataset_heart_dx
# WHERE restbps >= 140
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 5 rows affected.
# [(140, 0), (160, 0), (150, 0), (140, 1), (140, 1)]

# %%
# %%sql
#
# SELECT
#     `exercise angina`,
#     COUNT(restbps)
# FROM cleveland_dataset_heart_dx
# WHERE restbps >= 140
# GROUP BY `exercise angina`
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(0, 203), (1, 168)]

# %% [markdown]
# A tabular representation of the presence (1) and abscense(0) of exercise angina in relation to high systolic blood pressure (>=140).

# %%
# %%sql
#
# SELECT cholesterol, `exercise angina`
# FROM cleveland_dataset_heart_dx
# WHERE cholesterol >= 200
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 10 rows affected.
# [(289.0, 0),
#  (283.0, 0),
#  (214.0, 1),
#  (339.0, 0),
#  (237.0, 0),
#  (208.0, 0),
#  (207.0, 1),
#  (284.0, 0),
#  (211.0, 0),
#  (204.0, 0)]

# %% [markdown]
# A tabular distribution of the presence (1) and abscense(0) of exercise angina in relation to the different intividual high cholesterol (>200) levels.

# %%
# %%sql
#
# SELECT
#     `exercise angina`,
#     COUNT(cholesterol)
# FROM cleveland_dataset_heart_dx
# WHERE cholesterol > 200
# GROUP BY `exercise angina`
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/clevelanddata
# 2 rows affected.
# [(0, 518), (1, 330)]

# %% [markdown]
# The presence (1) and abscense(0) of exercise angina in relation to high cholesterol (>200).
